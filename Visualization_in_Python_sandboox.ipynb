# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewMichael2020/SolvingMathProblems/blob/main/Visualization_in_Python_sandboox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
random.randint(1,10000000000000)
# Out:
# 932983393644

# %%
import numpy as np
import math

def myFactorial (val):
  return np.prod(np.arange(1, val + 1))

print (myFactorial (5))

print (math.factorial(5))
# Out:
# 120
# 120

# %%
import numpy as np
import numpy.random
import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)
a = np.random.randn(10)
plt.plot(a)
plt.show()

plt.subplot(1, 2, 2)
a = np.random.randn(10)
plt.plot(a)
plt.show()

# %%
plt.subplot(2, 2, 1)
a = np.random.randn(10)
plt.plot(a)
plt.show()

plt.subplot(2, 2, 2)
b = np.random.randn(10)
plt.plot(b)
plt.show()

# %%
for i in range (9) :
    plt.subplot(3,3,i+1)
    plt.plot(np.random.randn(7))
    plt.show()

# %%
fig, ax = plt.subplots(1,3)
xp = np.arange(10)
ax[0].plot ( xp, xp**2, 'b' )
ax[1].plot ( xp, np.sqrt( xp ), 'r' )
ax[2].plot ( xp, np.exp( xp ), 'g' )

plt.show()

# %%
#@title
fig, ax = plt.subplots(2,2)
# print(np.shape(ax))


ax [0,0] = plt.plot(np.random.randn(4,4))
ax[0,1] = plt.plot(np.random.randn(4,4))
# ax[1,0] = plt.plot(np.random.randn(4,4))
# ax[1,1] = plt.plot(np.random.randn(4,4))
plt.show() #Why is this not showing corrently???

# %%
M = np.random.randint(1, 11, size = (4,4))
print(M)
M.flatten()
# Out:
# [[ 1  4  7  5]
#  [ 7  5  5  1]
#  [ 7  8  6  5]
#  [10 10  7  1]]
# array([ 1,  4,  7,  5,  7,  5,  5,  1,  7,  8,  6,  5, 10, 10,  7,  1])

# %%
fig, ax = plt.subplots(3, 3, figsize=(8, 8))
for i in ax.flatten():
    i.plot(np.random.randn(5, 3))
plt.show()

# %%
x = np.linspace (-3,3, 100)
print(x)
plt.plot(x,x, label = 'y = x')
plt.plot(x, x**2, label = 'y = x squared')
plt.plot(x, x**3, label = 'y = x cubed')
plt.legend()
plt.show()
# Out:
# [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576 -2.6969697
#  -2.63636364 -2.57575758 -2.51515152 -2.45454545 -2.39393939 -2.33333333
#  -2.27272727 -2.21212121 -2.15151515 -2.09090909 -2.03030303 -1.96969697
#  -1.90909091 -1.84848485 -1.78787879 -1.72727273 -1.66666667 -1.60606061
#  -1.54545455 -1.48484848 -1.42424242 -1.36363636 -1.3030303  -1.24242424
#  -1.18181818 -1.12121212 -1.06060606 -1.         -0.93939394 -0.87878788
#  -0.81818182 -0.75757576 -0.6969697  -0.63636364 -0.57575758 -0.51515152
#  -0.45454545 -0.39393939 -0.33333333 -0.27272727 -0.21212121 -0.15151515
#  -0.09090909 -0.03030303  0.03030303  0.09090909  0.15151515  0.21212121
#   0.27272727  0.33333333  0.39393939  0.45454545  0.51515152  0.57575758
#   0.63636364  0.6969697   0.75757576  0.81818182  0.87878788  0.93939394
#   1.          1.06060606  1.12121212  1.18181818  1.24242424  1.3030303
#   1.36363636  1.42424242  1.48484848  1.54545455  1.60606061  1.66666667
# ...

# %%
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

x = np.linspace (-3,3, 100)
print(x)
plt.plot(x,x)
plt.plot(x, x**2)
plt.plot(x, x**3)
plt.legend(['y = x',  'y = x squared', 'y = x cubed'])
plt.xlabel('x')
plt.ylabel ('f(x)')
plt.xlim(x[0], x[-1]) # extens lines to limits of the box to show that 
        #function is contiguos 
plt.ylim (x[0], x[-1]) # better to hardcode to -10, 10
plt.title('Plot of functions')
# plt.axis('square')
# plt.gca().set_aspect('auto')
# plt.gca().set_aspect('equal')
# plt.gca().set_aspect(0.9)
plt.gca().set_aspect(1/plt.gca().get_data_ratio()) # To get a square plot precisely
plt.show()
# Out:
# [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576 -2.6969697
#  -2.63636364 -2.57575758 -2.51515152 -2.45454545 -2.39393939 -2.33333333
#  -2.27272727 -2.21212121 -2.15151515 -2.09090909 -2.03030303 -1.96969697
#  -1.90909091 -1.84848485 -1.78787879 -1.72727273 -1.66666667 -1.60606061
#  -1.54545455 -1.48484848 -1.42424242 -1.36363636 -1.3030303  -1.24242424
#  -1.18181818 -1.12121212 -1.06060606 -1.         -0.93939394 -0.87878788
#  -0.81818182 -0.75757576 -0.6969697  -0.63636364 -0.57575758 -0.51515152
#  -0.45454545 -0.39393939 -0.33333333 -0.27272727 -0.21212121 -0.15151515
#  -0.09090909 -0.03030303  0.03030303  0.09090909  0.15151515  0.21212121
#   0.27272727  0.33333333  0.39393939  0.45454545  0.51515152  0.57575758
#   0.63636364  0.6969697   0.75757576  0.81818182  0.87878788  0.93939394
#   1.          1.06060606  1.12121212  1.18181818  1.24242424  1.3030303
#   1.36363636  1.42424242  1.48484848  1.54545455  1.60606061  1.66666667
# ...

# %%
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

# Doing same things with subplots instead of plt.

fig, ax = plt.subplots()
ax.plot(x,x)
ax.plot(x, x**2)
ax.plot(x, x**3)
ax.legend(['y = x',  'y = x squared', 'y = x cubed'])
ax.set_xlabel('x')
ax.set_ylabel ('f(x)')
ax.set_title ('This is a plot of three functions')
ax.set_xlim(x[0], x[-1]) # extens lines to limits of the box to show that 
        #function is contiguos 
ax.set_ylim (x[0], x[-1]) # better to hardcode to -10, 10
# plt.axis('square')
# plt.gca().set_aspect('auto')
# plt.gca().set_aspect('equal')
# plt.gca().set_aspect(0.9)
ax.set_aspect (1/ ax.get_data_ratio())
ax.grid()

# %%
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

# Doing same things with subplots instead of plt.

x = np.linspace (0, 10, 100)

fig, ax = plt.subplots()
for i in np.linspace (0, 1, 50):
  ax.plot(x, x**i, color = [i/2, 0, i]) ## [i, i, i ] gives grey. 

# ax.legend(['y = x',  'y = x squared', 'y = x cubed'])
ax.set_xlabel('x')
ax.set_ylabel ('f(x)')
ax.set_title ('This is a plot of a power function')
ax.set_xlim(0, x[-1]) # extens lines to limits of the box to show that 
        #function is contiguos 
ax.set_ylim (0, x[-1]) # better to hardcode to -10, 10
# plt.axis('square')
# plt.gca().set_aspect('auto')
# plt.gca().set_aspect('equal')
# plt.gca().set_aspect(0.9)
ax.set_aspect (1/ ax.get_data_ratio())
ax.grid()

# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

x = np.arange (-5,6)
y = x ** 2

fig, ax = plt.subplots()
ax.plot ( x, y, 'ko-', markerfacecolor = 'w', markersize = 15)
ax.annotate ('This is a data point', (x[3], y[3]), size = 10, arrowprops = dict(), 
             xycoords = 'data', xytext = (0,20), 
             horizontalalignment = 'center')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)

x = np.arange (-5,6)
y = x ** 2 + np.cos(x) * 10

minimumPoint = np.argmin ( y )
annotationText = 'min ( %g , %.2f )' %(x[minimumPoint], y[minimumPoint])

fig, ax = plt.subplots()

ax.plot ( x, y, 'ko-', markerfacecolor = 'maroon', markersize = 15)

ax.annotate (annotationText, (x[minimumPoint], y[minimumPoint]), size = 10, 
             arrowprops = dict(color = 'maroon', arrowstyle = 'wedge'), 
             xycoords = 'data', xytext = (x[int(len(x)/2)] , int (np.max (y) * .8)),
             horizontalalignment = 'center')

ax.set_xlabel ('x variable')
ax.set_ylabel ('y = x ** 2 + cos(x) * 10')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)
import seaborn as sns
import pandas as pd


n = 200
D = np.zeros ((n,2))

D [:, 0] = np.linspace (0, 10, n) + np.random.randn(n) # populating first column
D [:, 1] = D [:, 0] ** 2 + np.random.randn (n)*5

sns.jointplot (D[:, 0], D[:, 1])
plt.show()

print ('________________________________________________________')

D = np.zeros ((n,2))

D [:, 0] = np.linspace (0, 10, n) + np.random.randn(n) # populating first column
D [:, 1] = x ** 2 + np.random.randn (n)*5

var1 = 'One'
var2 = "Two"
df = pd.DataFrame (data = D, columns = [var1, var2] )

sns.jointplot (x, y, data = df, kind = 'kde')
plt.show()


print ('________________________________________________________')


x = np.linspace (-1, 1, n)

y1 = x ** 2
y2 = np.sin ( 3 * x )
y3 = np.exp ( -10 * x ** 2  )

# plt.plot (x, y2, 'y3')

sns.scatterplot ( x = y1 , y = y2, hue = y3, legend = False, palette='icefire')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ________________________________________________________
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ________________________________________________________

# %%
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
plt=reload(plt)
import seaborn as sns
import pandas as pd


n = 200


x = np.linspace (-1, 1, n)

y1 = x ** 2
y2 = np.sin ( 3 * x )
y3 = np.exp ( -10 * x ** 2  )

# plt.plot (x, y2, 'y3')

sns.scatterplot ( x = y1 , y = y2, hue = y3, legend = False, palette='icefire')
plt.show()


sns.regplot (df.columns [0], df.columns [1], data = df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
import numpy as np
import matplotlib.pyplot as plt

m = 3
n = 5

M = np.random.randint (0,10, size = (m,n))
print (M)
plt.imshow (M)

for i in range (m) :
  for j in range (n):
    plt.text (j, i, str ( M [i, j] ) )

plt.colorbar()
plt.show()
# Out:
# [[6 0 8 4 3]
#  [7 0 0 8 1]
#  [5 2 3 6 1]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread 

img = imread ('https://upload.wikimedia.org/wikipedia/en/8/86/Einstein_tongue.jpg')

plt.imshow (img)
plt.title ('Pitcure')
plt.show()

print (np.shape(img))

plt.imshow (img)
plt.title ('Pitcure')
plt.show()

print (np.shape(img.flatten()))

plt.hist (img.flatten(), bins = 100)
plt.show()

plt.imshow (255 - img, cmap = 'Greys', vmin = 5, vmax = 250)
plt.xticks([])
plt.yticks ([])
plt.colorbar()
plt.show()
# Out:
# (286, 230)
# (65780,)

# %%
# Hilbert Matrix

N = 1000

H = np.zeros ((N, N))

for i in range (1, N + 1) :
  for j in range (1, N + 1) :
    H [i - 1,j -1 ] = 1 / (i + j - 1)

import seaborn as sns
sns.heatmap (H, vmin = 0, vmax = 0.002)
plt.show()

# %%
# Export

import numpy as np
import matplotlib.pyplot as plt
from imageio import imread 

# Changes / increases resolution for *all* visualizations below:
from IPython import display
display.set_matplotlib_formats ( 'svg' )

# To actually work with files:
from google.colab import files 


x = np.linspace (0.5, 5.0, 15)
y1 = np.log ( x )
y2 = 2 - np.sqrt ( x )

plt.plot (x, y1, 'bo-', label = 'Log')
plt.plot (x, y2, 'rs-', label = 'Sqrt')
plt.legend()

plt.savefig ('Test image.pdf')

files.download ('Test image.pdf')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from imageio import imread 

# Changes / increases resolution for *all* visualizations below:
from IPython import display
display.set_matplotlib_formats ( 'svg' )

# To actually work with files:
from google.colab import files 

N = 10000
sx = np.zeros(N)
sy = np.zeros(N)

for i in range(1, N):
    k = np.random.randint(1, 4)
    sx[i] = sx[i - 1] / 2 + k - 1
    sy[i] = sy[i - 1] / 2
    if k == 2:
        sy[i] += 2
plt.plot(sx, sy, 'k.', markersize=3, color = 'purple')
plt.title('Sierpinski Triangle')
plt.axis('off')
plt.show()
